# %% [markdown]
# ### Importar librerías

# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,2))

# %% [markdown]
# ### Shape

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr
# Out:
# array([[9, 6],
#        [8, 9],
#        [4, 2]])

# %% [markdown]
# ### Reshape

# %%
arr.reshape(1,6)
# Out:
# array([[9, 6, 8, 9, 4, 2]])

# %%
arr.reshape(2,3)
# Out:
# array([[9, 6, 8],
#        [9, 4, 2]])

# %%
np.reshape(arr,(1,6))
# Out:
# array([[9, 6, 8, 9, 4, 2]])

# %%
arr
# Out:
# array([[9, 6],
#        [8, 9],
#        [4, 2]])

# %%
np.reshape(arr,(2,3),'C')
# Out:
# array([[9, 6, 8],
#        [9, 4, 2]])

# %%
np.reshape(arr,(2,3),'F')
# Out:
# array([[9, 4, 9],
#        [8, 6, 2]])

# %%
np.reshape(arr,(2,3),'A')
# Out:
# array([[9, 6, 8],
#        [9, 4, 2]])
